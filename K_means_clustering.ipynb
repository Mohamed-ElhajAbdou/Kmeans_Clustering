# %%
# k-means clustering
from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# define dataset
X, _ = make_classification(n_samples=1000, n_features=2, n_informative=2, n_redundant=0, n_clusters_per_class=1, random_state=4)

# %%
# define the model
model = KMeans(n_clusters=4)

# %%
# fit the model
model.fit(X)
# Out:
# KMeans(n_clusters=4)

# %%
# assign a cluster to each example
yhat = model.predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster

# %%
clusters
# Out:
# array([0, 1, 2, 3])

# %%
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
     #create scatter of these samples
    pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# %matplotlib inline

# %%
X= -2 * np.random.rand(100,2)

# %%
X1 = 1 + 2 * np.random.rand(50,2)
X[50:100, :] = X1
plt.scatter(X[ : , 0], X[ :, 1], s = 50, c = 'b')
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
Kmean = KMeans(n_clusters=2)

# %%
Kmean.fit(X)
# Out:
# KMeans(n_clusters=2)

# %%
Kmean.cluster_centers_
# Out:
# array([[ 1.94068707,  2.06693261],
#        [-1.00037578, -0.87897116]])

# %%
plt.scatter(X[ : , 0], X[ : , 1], s =50, c='b')
plt.scatter(-1.00037578, -0.87897116, s=200, c='g')
plt.scatter(1.94068707, 2.06693261, s=200, c='r')
plt.show()

# %%
Kmean.labels_
sample_test=np.array([-3.0,-3.0])

second_test=sample_test.reshape(1, -1)
Kmean.predict(second_test)
# Out:
# array([1])

# %%
from sklearn.datasets import make_blobs
X, y = make_blobs(n_samples=100, centers=5, random_state=101)

# %%
plt.rcParams.update({'figure.figsize':(10,7.5), 'figure.dpi':100})
plt.scatter(X[:, 0], X[:, 1])

# %%
y
# Out:
# array([3, 1, 4, 3, 0, 0, 2, 4, 1, 1, 0, 1, 1, 0, 0, 0, 2, 0, 4, 0, 4, 3,
#        4, 0, 0, 3, 1, 3, 4, 0, 1, 2, 4, 1, 1, 4, 3, 3, 1, 0, 2, 4, 0, 0,
#        2, 4, 3, 1, 1, 1, 3, 3, 2, 4, 1, 3, 0, 2, 4, 4, 1, 3, 2, 2, 4, 0,
#        3, 4, 1, 3, 4, 3, 2, 3, 2, 0, 2, 3, 1, 2, 1, 4, 2, 4, 3, 2, 2, 0,
#        1, 2, 4, 0, 3, 2, 1, 4, 3, 2, 2, 0])

# %%
from sklearn.cluster import KMeans

# %%
Cluster = KMeans(n_clusters=5)
Cluster.fit(X)
y_pred = Cluster.predict(X)

# %%
y_pred
# Out:
# array([2, 1, 3, 2, 0, 0, 4, 3, 1, 1, 0, 1, 1, 0, 0, 0, 4, 0, 3, 0, 3, 2,
#        3, 0, 0, 2, 1, 2, 3, 0, 1, 4, 3, 1, 1, 3, 2, 2, 1, 0, 4, 3, 0, 0,
#        4, 3, 2, 1, 1, 1, 2, 2, 4, 3, 1, 2, 0, 4, 3, 3, 1, 2, 4, 4, 3, 0,
#        2, 3, 1, 2, 3, 2, 4, 2, 4, 0, 4, 2, 1, 4, 1, 3, 4, 3, 2, 4, 4, 0,
#        1, 4, 3, 0, 2, 4, 1, 3, 2, 4, 4, 0])

# %%
for i in range (0,len(X)):
    
    print('The X-locations (x,y)-->',X[i],'while the Pred which cluster',y_pred[i])
# Out:
# The X-locations (x,y)--> [-4.95836863  5.96425277] while the Pred which cluster 2
# The X-locations (x,y)--> [-10.56433263  -5.95908897] while the Pred which cluster 1
# The X-locations (x,y)--> [ 5.03973453 -5.91474793] while the Pred which cluster 3
# The X-locations (x,y)--> [-4.24393374  7.46294311] while the Pred which cluster 2
# The X-locations (x,y)--> [0.29639341 2.06317757] while the Pred which cluster 0
# The X-locations (x,y)--> [-1.37811338  0.25423232] while the Pred which cluster 0
# The X-locations (x,y)--> [3.74699958 6.26688185] while the Pred which cluster 4
# The X-locations (x,y)--> [ 4.60888633 -6.82802632] while the Pred which cluster 3
# The X-locations (x,y)--> [-9.2834887  -7.04901491] while the Pred which cluster 1
# The X-locations (x,y)--> [-9.04448516 -4.48554835] while the Pred which cluster 1
# The X-locations (x,y)--> [1.13567847 1.48631141] while the Pred which cluster 0
# ...

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.rcParams.update({'figure.figsize':(10,7.5)})

# %%
# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []            ## total distances from the centeriods
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    print('Cost_Function=',kmeans.inertia_,'with', i, 'Clusters')
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# Cost_Function= 6590.911023009175 with 1 Clusters
# Cost_Function= 3198.837229552225 with 2 Clusters
# Cost_Function= 1197.8007257715005 with 3 Clusters
# Cost_Function= 540.6460706067454 with 4 Clusters
# Cost_Function= 201.8137473656779 with 5 Clusters
# Cost_Function= 183.14932014130105 with 6 Clusters
# Cost_Function= 161.44239052378325 with 7 Clusters
# Cost_Function= 143.11972124548035 with 8 Clusters
# Cost_Function= 123.9394858297158 with 9 Clusters
# Cost_Function= 116.05632454301387 with 10 Clusters

# %%
# Fitting K-Means to the dataset
Cluster = KMeans(n_clusters=4)
Cluster.fit(X)
y_pred = Cluster.predict(X)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.rcParams.update({'figure.figsize':(10,7.5)})

# %%
# Fitting K-Means to the dataset
Cluster = KMeans(n_clusters=5)
Cluster.fit(X)
y_pred = Cluster.predict(X)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.rcParams.update({'figure.figsize':(10,7.5)})
